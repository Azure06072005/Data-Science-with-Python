# %% [markdown]
# <a href="https://colab.research.google.com/github/Azure06072005/Data-Science-with-Python/blob/main/CS116_eda_notebook_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install neccesary libraries
# !pip install polars
# Out:
# ERROR: unknown command "Install" - maybe you meant "install"

# %%
import os
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Define filepath
BASE_DIR = '/content/drive/MyDrive/recommendation_dataset'
OUT_DIR = os.path.join(BASE_DIR, 'eda_outputs')
os.makedirs(OUT_DIR, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
GLOB_PUR = os.path.join(BASE_DIR, "sales_pers.purchase_history_daily_chunk_*.parquet")
print("Tải dữ liệu thành công!")
# Out:
# Tải dữ liệu thành công!

# %%
lf_pur = pl.read_parquet(GLOB_PUR)
print(lf_pur)
# Out:
# shape: (35_729_825, 16)
# ┌────────────┬───────────┬───────────┬───────────┬───┬──────────┬──────────┬───────────┬───────────┐
# │ timestamp  ┆ user_id   ┆ item_id   ┆ event_typ ┆ … ┆ payment  ┆ location ┆ discount  ┆ is_delete │
# │ ---        ┆ ---       ┆ ---       ┆ e         ┆   ┆ ---      ┆ ---      ┆ ---       ┆ d         │
# │ i64        ┆ str       ┆ str       ┆ ---       ┆   ┆ str      ┆ i32      ┆ decimal[3 ┆ ---       │
# │            ┆           ┆           ┆ str       ┆   ┆          ┆          ┆ 8,4]      ┆ bool      │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪══════════╪══════════╪═══════════╪═══════════╡
# │ 1735064221 ┆ ca12702dd ┆ 711500000 ┆ Purchase  ┆ … ┆ VietQR   ┆ 656      ┆ 0.0000    ┆ false     │
# │            ┆ f55acaa9f ┆ 0004      ┆           ┆   ┆          ┆          ┆           ┆           │
# │            ┆ b767e10fa ┆           ┆           ┆   ┆          ┆          ┆           ┆           │
# ...

# %%
# Set Polars display options to show all rows
pl.Config.set_fmt_str_lengths(100)
pl.Config.set_tbl_cols(-1)

# Display the entire DataFrame
print(lf_pur)
# Out:
# shape: (35_729_825, 16)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬────────┐
# │ tim ┆ use ┆ ite ┆ eve ┆ eve ┆ pri ┆ dat ┆ qua ┆ cus ┆ cre ┆ upd ┆ cha ┆ pay ┆ loc ┆ dis ┆ is_del │
# │ est ┆ r_i ┆ m_i ┆ nt_ ┆ nt_ ┆ ce  ┆ e_k ┆ nti ┆ tom ┆ ate ┆ ate ┆ nne ┆ men ┆ ati ┆ cou ┆ eted   │
# │ amp ┆ d   ┆ d   ┆ typ ┆ val ┆ --- ┆ ey  ┆ ty  ┆ er_ ┆ d_d ┆ d_d ┆ l   ┆ t   ┆ on  ┆ nt  ┆ ---    │
# │ --- ┆ --- ┆ --- ┆ e   ┆ ue  ┆ dec ┆ --- ┆ --- ┆ id  ┆ ate ┆ ate ┆ --- ┆ --- ┆ --- ┆ --- ┆ bool   │
# │ i64 ┆ str ┆ str ┆ --- ┆ --- ┆ ima ┆ i32 ┆ i32 ┆ --- ┆ --- ┆ --- ┆ str ┆ str ┆ i32 ┆ dec ┆        │
# │     ┆     ┆     ┆ str ┆ dec ┆ l[3 ┆     ┆     ┆ i32 ┆ dat ┆ dat ┆     ┆     ┆     ┆ ima ┆        │
# │     ┆     ┆     ┆     ┆ ima ┆ 8,4 ┆     ┆     ┆     ┆ eti ┆ eti ┆     ┆     ┆     ┆ l[3 ┆        │
# │     ┆     ┆     ┆     ┆ l[3 ┆ ]   ┆     ┆     ┆     ┆ me[ ┆ me[ ┆     ┆     ┆     ┆ 8,4 ┆        │
# ...

# %%
print("Shape:", lf_pur.shape)
print("Columns:", lf_pur.columns)
print("Dtypes:", lf_pur.dtypes)
print("Schema:", lf_pur.schema)
# Out:
# Shape: (35729825, 16)
# Columns: ['timestamp', 'user_id', 'item_id', 'event_type', 'event_value', 'price', 'date_key', 'quantity', 'customer_id', 'created_date', 'updated_date', 'channel', 'payment', 'location', 'discount', 'is_deleted']
# Dtypes: [Int64, String, String, String, Decimal(precision=38, scale=4), Decimal(precision=38, scale=4), Int32, Int32, Int32, Datetime(time_unit='us', time_zone=None), Datetime(time_unit='us', time_zone=None), String, String, Int32, Decimal(precision=38, scale=4), Boolean]
# ...

# %%
list(zip(lf_pur.columns, lf_pur.dtypes))
# Out:
# [('timestamp', Int64),
#  ('user_id', String),
#  ('item_id', String),
#  ('event_type', String),
#  ('event_value', Decimal(precision=38, scale=4)),
#  ('price', Decimal(precision=38, scale=4)),
#  ('date_key', Int32),
#  ('quantity', Int32),
#  ('customer_id', Int32),
#  ('created_date', Datetime(time_unit='us', time_zone=None)),
#  ('updated_date', Datetime(time_unit='us', time_zone=None)),
#  ('channel', String),
#  ('payment', String),
#  ('location', Int32),
#  ('discount', Decimal(precision=38, scale=4)),
#  ('is_deleted', Boolean)]
