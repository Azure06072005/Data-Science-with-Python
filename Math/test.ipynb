# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
u = np.array([1,3])
v = np.array([2,4])
x__coords, y__coords = zip(u,v)
plt.scatter(x__coords,y__coords, color = ["r", "b"])
plt.axis([0,10,0,10])
plt.grid()
plt.show()
